# %%
#Doing calculation the python way

#1

width = 17
height = 12.0
delimiter = '.'

# a)  width/2 = 8.5 type float

# b) width/2.0 = 8.5 type float

# c) height/3 = 4 type float

# d) 1 + 2 * 5 = 11  type int

# e) delimiter * 5 = ..... type str

#verification

print(width/2)
print(width/int(2.0)) # convertir 2.0 en int car 2.0 = 2
print(height/3)

l = 1 + 2 * 5 
print(l)
print(delimiter * 5)

#a)8.5
#b)8.5
#c)4.0
#d)11
#e.....
# Out:
# 8.5
# 8.5
# 4.0
# 11
# .....

# %%
#2

r = 5
pi = 3.1415926535897931
Vs = 4*pi*r*r*r/3
print(Vs)
# Out:
# 523.5987755982989

# %%
#Knowing more about data types and their operations

#1

a = 1

b = 5.0

c = "ten"

type(a) is int #true
type(b) is float #true
# Out:
# True

# %%
#2

#(i) int-int

a = 1

b = 5.0

c = "ten"

h = 4

print(a+h) # 5 (int)

#(ii) int-float

print(a + b)  # give 6.0 (float) !!ouf surprise

#(iii) float-float

d = 2.0
print( b+d)  # 7.0 (float)

# (iv) float-str

# print(b + c) #  error !!ouf  because b is not str 


#(v) str-str

e = "toni"

print(c + e) #give tentoni (str)

# %%
# 3 

#  *

a = 1

b = 5.0

c = "ten"

h = 4

print(a*h) # 4 (int)

#(ii) int-float

print(a * b)  # give 5.0 (float) !!ouf surprise

#(iii) float-float

d = 2.0
print( b*d)  # 10.0 (float)

# (iv) float-str

#print(b*c) #  error !!ouf  


#(v) str-str

e = "toni"

#print(c*e) #give tentoni (str) # error





#  /

a = 1

b = 5.0

c = "ten"

h = 4

print(a/h) # 0.25 (int)

#(ii) int-float

print(a / b)  # give 0.2 (float) !!ouf surprise

#(iii) float-float

d = 2.0
print( b/d)  # 2.5 (float)

# (iv) float-str

#print(b/c) #  error !!ouf  


#(v) str-str

e = "toni"

#print(c/e) #give tentoni (str) # error





#  -

a = 1

b = 5.0

c = "ten"

h = 4

print(a-h) # -3 (int)

#(ii) int-float

print(a - b)  # give -4.0 (float) !!ouf surprise

#(iii) float-float

d = 2.0
print( b-d)  # 3.0 (float)

# (iv) float-str

#print(b-c) #  error !!ouf  


#(v) str-str

e = "toni"

#print(c-e) #give tentoni (str) # error


#  %

a = 1

b = 5.0

c = "ten"

h = 4

print(a%h) # 1 (int)

#(ii) int-float

print(a % b)  # give 1.0 (float) !!ouf surprise

#(iii) float-float

d = 2.0
print( b%d)  # 1.0 (float)

# (iv) float-str

#print(b%c) #  error !!ouf  


#(v) str-str

e = "toni"

#print(c%e) #give tentoni (str) # error





#  >

a = 1

b = 5.0

c = "ten"

h = 4

print(a>h) # false 

#(ii) int-float

print(a > b)  # give false  !!ouf 

#(iii) float-float

d = 2.0
print( b>d)  # true 

# (iv) float-str

#print(b>c) #  error !!ouf  


#(v) str-str

e = "toni"

print(c>e)  # fasle  !!!ouf surprise




#  ==

a = 1

b = 5.0

c = "ten"

h = 4

print(a==h) # false

#(ii) int-float

print(a == b)  # false

#(iii) float-float

d = 2.0
print( b==d)  # false

# (iv) float-str

#print(b==c) #  error !!ouf  


#(v) str-str

e = "toni"

print(c==e)  # false
# Out:
# 4
# 5.0
# 10.0
# 0.25
# 0.2
# 2.5
# -3
# -4.0
# 3.0
# 1
# 1.0
# 1.0
# False
# False
# True
# False
# False
# False
# False
# False

# %%
# 4


help(int)

help(float)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...
